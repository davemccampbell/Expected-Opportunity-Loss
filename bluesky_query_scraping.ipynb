# %%
from atproto import Client

client = Client()
client.login('davemccampbell.bsky.social', 'redacted')
# Out:
# ProfileViewDetailed(did='did:plc:swpbmdrzk7r3vs5hdibfxwbf', handle='davemccampbell.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=0, labeler=False, lists=0, starter_packs=0, py_type='app.bsky.actor.defs#profileAssociated'), avatar=None, banner=None, created_at='2023-08-05T18:51:14.525Z', description=None, display_name=None, followers_count=4, follows_count=15, indexed_at='0001-01-01T00:00:00.000Z', joined_via_starter_pack=None, labels=[], pinned_post=None, posts_count=1, viewer=ViewerState(blocked_by=False, blocking=None, blocking_by_list=None, followed_by=None, following=None, known_followers=KnownFollowers(count=3, followers=[ProfileViewBasic(did='did:plc:av4avpninw2mujyfmiox3vql', handle='bdmoore.bsky.social', associated=ProfileAssociated(chat=ProfileAssociatedChat(allow_incoming='following', py_type='app.bsky.actor.defs#profileAssociatedChat'), feedgens=None, labeler=
# ...

# %%
import requests

# Updated endpoint URL
login_url = "https://bsky.social/xrpc/com.atproto.server.createSession"
login_payload = {
    "identifier": "davemccampbell.bsky.social",
    "password": "redacted"
}

login_response = requests.post(login_url, json=login_payload)

# Check the status code
print(f"Status Code: {login_response.status_code}")

# Print the raw response text
print(login_response.text)

# If the status code is 200, parse the JSON
if login_response.status_code == 200:
    session_data = login_response.json()

    # Extract tokens
    access_token = session_data.get('accessJwt')
    refresh_token = session_data.get('refreshJwt')

    print(f"Access Token: {access_token}")
    print(f"Refresh Token: {refresh_token}")
else:
    print("Failed to log in. Check your credentials and try again.")
# Out:
# Status Code: 200
# ...

# %%
# import requests

# # Your access token
# access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# # Replace with the actual endpoint you want to use
# url = "https://bsky.social/xrpc/app.bsky.feed.getTimeline"
# headers = {
#     "Authorization": f"Bearer {access_token}",
# }

# response = requests.get(url, headers=headers)
# data = response.json()

# # Print the entire response to understand its structure
# print(data)

# %%
import requests

# Your access token
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxNTEwOTM3LCJleHAiOjE3MzE1MTgxMzcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.EhBe53SLwcqjdREwOP3QdnbE7C9ey_zlkzFZxCMRdr4dMC878bMOJF0uu5a1Xj96xYOIRLfQEJ08KrkNoUb2ZA"
# Hypothetical search endpoint (replace with the actual one)
url = "https://bsky.app/search?q=kpbs"
params = {
    "query": "kpbs"
}
headers = {
    "Authorization": f"Bearer {access_token}",
}

response = requests.get(url, headers=headers, params=params)

# Print the status code and raw response text
print(f"Status Code: {response.status_code}")
print(response.text)
# Out:
# Status Code: 200
# <!DOCTYPE html>
# <html>
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, minimum-scale=1, viewport-fit=cover">
#   <meta name="referrer" content="origin-when-cross-origin">
#   <!--
#     Preconnect to essential domains
#   -->
#   <link rel="preconnect" href="https://bsky.social">
#   <link rel="preconnect" href="https://bsky.network">
#   <title>Bluesky</title>
#
#   <!-- Hello Humans! API docs at https://atproto.com -->
#
#   <link rel="preload" as="font" type="font/ttf" href="/static/media/InterVariable.c9f788f6e7ebaec75d7c.ttf">
#   <link rel="preload" as="font" type="font/ttf" href="/static/media/InterVariable-Italic.55d6a3f35e9b605ba6f4.ttf">
#
#   <style>
#     /**
#      * Minimum styles required to render splash.
#      *
#      * ALL OTHER STYLES BELONG IN `src/style.css`
#      *
#      * THIS NEEDS TO BE DUPLICATED IN `bskyweb/templates/base.html`
#      */
#     @font-face {
# ...

# %%
import requests

# Your access token
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# Search endpoint for querying posts
url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
params = {
    "q": "kpbs",
    "sort": "latest",  # You can use "top" if you prefer
    "limit": 100  # Adjust the limit as needed
}
headers = {
    "Authorization": f"Bearer {access_token}",
}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# # Print the entire response to understand its structure
# print(data)

# Print the keys to inspect the structure
print(data.keys())
# Out:
# dict_keys(['posts', 'cursor'])

# %%
import requests

# Your access token
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# Search endpoint for querying posts
url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
params = {
    "q": "kpbs",
    "sort": "latest",  # You can use "top" if you prefer
    "limit": 100  # Adjust the limit as needed
}
headers = {
    "Authorization": f"Bearer {access_token}",
}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# Print the first post to understand its structure
if 'posts' in data:
    print(data['posts'][0])
# Out:
# {'uri': 'at://did:plc:itf2itgfmunntgjjwsvvsnwp/app.bsky.feed.post/3lab2om5lyz2z', 'cid': 'bafyreifanyz3ikyh3v3nebis4u64rbgaf4iasbr7nqngtyfide2cun7i2e', 'author': {'did': 'did:plc:itf2itgfmunntgjjwsvvsnwp', 'handle': 'ilove.computer', 'displayName': 'ℹ️❤️🖥 aka Compy-chan ', 'avatar': 'https://cdn.bsky.app/img/avatar/plain/did:plc:itf2itgfmunntgjjwsvvsnwp/bafkreib7dgmlog733dw6tcz42w5ob6tzcn6lyqufwbqize2tsuzpzprpbq@jpeg', 'associated': {'chat': {'allowIncoming': 'following'}}, 'viewer': {'muted': False, 'blockedBy': False}, 'labels': [], 'createdAt': '2023-06-01T17:05:56.899Z'}, 'record': {'$type': 'app.bsky.feed.post', 'createdAt': '2024-11-06T05:55:10.273Z', 'langs': ['en'], 'reply': {'parent': {'cid': 'bafyreib2rzbzbz2nb7alzq6dfi4f3y66pp53q7egm7rq7icqbi7mkgetyy', 'uri': 'at://did:plc:tr4cft75d5yyfurquqoctgug/app.bsky.feed.post/3lab25zf4ym2y'}, 'root': {'cid': 'bafyreigwhnodpcgal6ejl2bi5mbvdwgtnvyjd4g7f6i2juunbcpanoy2iy', 'uri': 'at://did:plc:itf2itgfmunntgjjwsvvsnwp/app.bsky.feed.pos
# ...

# %%
import requests

# Your access token
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# Search endpoint for querying posts
url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
params = {
    "q": "kpbs",
    "sort": "latest",  # You can use "top" if you prefer
    "limit": 100  # Adjust the limit as needed
}
headers = {
    "Authorization": f"Bearer {access_token}",
}

response = requests.get(url, headers=headers, params=params)
data = response.json()

# Extract posts from the 'posts' key and access the 'text' field within 'record'
posts = [post['record']['text'] for post in data['posts']]
count_kpbs = sum(post.lower().count('kpbs') for post in posts)

print(f"'kpbs' mentioned {count_kpbs} times in the search results.")
# Out:
# 'kpbs' mentioned 114 times in the search results.

# %%
import requests

# Your access token
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# Search endpoint for querying posts
url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
params = {
    "q": "kpbs",
    "sort": "latest",
    "limit": 100  # Set limit to a smaller value and use pagination
}
headers = {
    "Authorization": f"Bearer {access_token}",
}

all_posts = []
has_more = True
cursor = None

while has_more:
    if cursor:
        params['cursor'] = cursor

    response = requests.get(url, headers=headers, params=params)
    data = response.json()

    if 'posts' in data:
        all_posts.extend(post['record']['text'] for post in data['posts'])
        cursor = data.get('cursor')  # Update the cursor for next page
        has_more = cursor is not None
    else:
        has_more = False

count_kpbs = sum(post.lower().count('kpbs') for post in all_posts)

print(f"'kpbs' mentioned {count_kpbs} times in the search results.")
# Out:
# 'kpbs' mentioned 132 times in the search results.

# %%
import requests

def get_monthly_mentions(access_token, month_start, month_end):
    # Search endpoint for querying posts
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    params = {
        "q": "kpbs",
        "sort": "latest",
        "since": month_start,
        "until": month_end,
        "limit": 100  # Set limit and handle pagination
    }
    headers = {
        "Authorization": f"Bearer {access_token}",
    }

    all_posts = []
    has_more = True
    cursor = None

    while has_more:
        if cursor:
            params['cursor'] = cursor

        response = requests.get(url, headers=headers, params=params)
        data = response.json()

        if 'posts' in data:
            all_posts.extend(post['record']['text'] for post in data['posts'])
            cursor = data.get('cursor')  # Update the cursor for next page
            has_more = cursor is not None
        else:
            has_more = False

    count_kpbs = sum(post.lower().count('kpbs') for post in all_posts)
    return count_kpbs

# Example usage
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# Define month ranges (YYYY-MM-DD format)
january_start = "2024-01-01"
january_end = "2024-01-31"

february_start = "2024-02-01"
february_end = "2024-02-29"
sept_start= "2023-09-01"
sept_end="2023-09-30"

# Get mentions for January
january_mentions = get_monthly_mentions(access_token, january_start, january_end)
print(f"'kpbs' mentioned {january_mentions} times in January 2024.")

# Get mentions for February
february_mentions = get_monthly_mentions(access_token, february_start, february_end)
print(f"'kpbs' mentioned {february_mentions} times in February 2024.")

# get mentions for September
sept_mentions = get_monthly_mentions(access_token, sept_start, sept_end)
print(f"'kpbs' mentioned {sept_mentions} times in september 2023.")
# Out:
# 'kpbs' mentioned 0 times in January 2024.
# 'kpbs' mentioned 0 times in February 2024.
# 'kpbs' mentioned 0 times in september 2023.

# %%
import requests

def get_monthly_mentions(access_token, month_start, month_end):
    # Search endpoint for querying posts
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    params = {
        "q": "kpbs",
        "sort": "latest",
        "since": month_start,
        "until": month_end,
        "limit": 100  # Set limit and handle pagination
    }
    headers = {
        "Authorization": f"Bearer {access_token}",
    }

    all_posts = []
    has_more = True
    cursor = None

    while has_more:
        if cursor:
            params['cursor'] = cursor

        response = requests.get(url, headers=headers, params=params)
        data = response.json()

        # Print data to inspect the structure
        print(f"Response for {month_start} to {month_end}:")
        print(data)

        if 'posts' in data:
            all_posts.extend(post['record']['text'] for post in data['posts'])
            cursor = data.get('cursor')  # Update the cursor for next page
            has_more = cursor is not None
        else:
            has_more = False

    count_kpbs = sum(post.lower().count('kpbs') for post in all_posts)
    return count_kpbs

# Example usage
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxMzYxNDU3LCJleHAiOjE3MzEzNjg2NTcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.StfzLu72UWH_t7-TIp7SuwtV3QcfpjJEVqejxw_yM6OIFNShQ_OA_E4wGNGM-GsWB3vTT5ZETGCIq11jlIeO7g"

# Define month ranges (YYYY-MM-DD format)
september_start = "2023-09-01"
september_end = "2023-09-30"

# Get mentions for September
september_mentions = get_monthly_mentions(access_token, september_start, september_end)
print(f"'kpbs' mentioned {september_mentions} times in September 2023.")
# Out:
# Response for 2023-09-01 to 2023-09-30:
# {'error': 'BadRequest', 'message': "invalid Datetime for 'since': Datetime syntax didn't validate via regex"}
# 'kpbs' mentioned 0 times in September 2023.

# %%
import requests

def get_monthly_mentions(access_token, month_start, month_end):
    # Search endpoint for querying posts
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    params = {
        "q": "kpbs",
        "sort": "latest",
        "since": month_start,
        "until": month_end,
        "limit": 100  # Set limit and handle pagination
    }
    headers = {
        "Authorization": f"Bearer {access_token}",
    }

    all_posts = []
    has_more = True
    cursor = None

    while has_more:
        if cursor:
            params['cursor'] = cursor

        response = requests.get(url, headers=headers, params=params)
        data = response.json()

        # Print data to inspect the structure
        print(f"Response for {month_start} to {month_end}:")
        print(data)

        if 'posts' in data:
            all_posts.extend(post['record']['text'] for post in data['posts'])
            cursor = data.get('cursor')  # Update the cursor for next page
            has_more = cursor is not None
        else:
            has_more = False

    count_kpbs = sum(post.lower().count('kpbs') for post in all_posts)
    return count_kpbs

# Example usage
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxNTEwOTM3LCJleHAiOjE3MzE1MTgxMzcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.EhBe53SLwcqjdREwOP3QdnbE7C9ey_zlkzFZxCMRdr4dMC878bMOJF0uu5a1Xj96xYOIRLfQEJ08KrkNoUb2ZA"

# Define month ranges with full datetime (YYYY-MM-DDTHH:MM:SSZ format)  note: kpbs left twitter april 17 2023
september_start = "2024-09-01T00:00:00Z"
september_end = "2024-09-30T23:59:59Z"

# Get mentions for September
september_mentions = get_monthly_mentions(access_token, september_start, september_end)
print(f"'kpbs' mentioned {september_mentions} times in September 2023.")
# Out:
# Response for 2024-09-01T00:00:00Z to 2024-09-30T23:59:59Z:
# ...

# %%
import requests
from datetime import datetime, timedelta

def get_monthly_mentions(access_token, month_start, month_end):
    # Search endpoint for querying posts
    url = "https://bsky.social/xrpc/app.bsky.feed.searchPosts"
    params = {
        "q": "kpbs",
        "sort": "latest",
        "since": month_start,
        "until": month_end,
        "limit": 100  # Set limit and handle pagination
    }
    headers = {
        "Authorization": f"Bearer {access_token}",
    }

    all_posts = []
    has_more = True
    cursor = None

    while has_more:
        if cursor:
            params['cursor'] = cursor

        response = requests.get(url, headers=headers, params=params)
        data = response.json()

        # Print data to inspect the structure
        print(f"Response for {month_start} to {month_end}:")
        print(data)

        if 'posts' in data:
            all_posts.extend(post['record']['text'] for post in data['posts'])
            cursor = data.get('cursor')  # Update the cursor for next page
            has_more = cursor is not None
        else:
            has_more = False

    count_kpbs = sum(post.lower().count('kpbs') for post in all_posts)
    return count_kpbs

# Example usage
access_token = "eyJ0eXAiOiJhdCtqd3QiLCJhbGciOiJFUzI1NksifQ.eyJzY29wZSI6ImNvbS5hdHByb3RvLmFjY2VzcyIsInN1YiI6ImRpZDpwbGM6c3dwYm1kcnprN3IzdnM1aGRpYmZ4d2JmIiwiaWF0IjoxNzMxNTEwOTM3LCJleHAiOjE3MzE1MTgxMzcsImF1ZCI6ImRpZDp3ZWI6bGlvbnNtYW5lLnVzLWVhc3QuaG9zdC5ic2t5Lm5ldHdvcmsifQ.EhBe53SLwcqjdREwOP3QdnbE7C9ey_zlkzFZxCMRdr4dMC878bMOJF0uu5a1Xj96xYOIRLfQEJ08KrkNoUb2ZA"

# Define month range from February 2024 to the current date
february_start = "2024-02-01T00:00:00Z"
current_date = datetime.utcnow()
current_date_str = current_date.strftime("%Y-%m-%dT%H:%M:%SZ")

# Get mentions from February 2024 to the current date
mentions_feb_to_now = get_monthly_mentions(access_token, february_start, current_date_str)
print(f"'kpbs' mentioned {mentions_feb_to_now} times from February 2024 to the current date.")
# Out:
# Response for 2024-02-01T00:00:00Z to 2024-11-13T15:28:54Z:
# ...

# %% [markdown]
# get users by month
